# %% [markdown]
# <a href="https://colab.research.google.com/github/aslanzade700/Colab/blob/main/Homework4V5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/ogut77/DataScience/master/insurance.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# Context in Insurance Data
# This dataset is often used to predict charges based on the other variables (age, sex, bmi, children, smoker, region). For example:
#
# Input Variables (X): age, sex, bmi, children, smoker, region (features used to make predictions).
#
# Output Variable (y): charges (what you’re trying to predict).

# %% [markdown]
# Describtion of variables
# 1. Age
# Description: The age of the individual (the insured person).
# Type: Numerical (integer).
# Example Values: 19, 45, 62, etc.
# Role in Insurance: Age is a key factor in determining insurance charges. Older individuals often have higher medical costs (and thus higher charges) due to increased health risks.
# 2. Sex
# Description: The gender of the individual.
# Type: Categorical (text or binary).
# Example Values: "male," "female"
# Role in Insurance: Gender can influence insurance charges because health risks and medical expenses may differ between males and females (e.g., pregnancy-related costs for females).
# 3. BMI (Body Mass Index)
# Description: A measure of body fat based on height and weight (calculated as weight in kg divided by height in meters squared).
# Type: Numerical (float).
# Example Values: 25.3, 30.1, 18.5, etc.
# Role in Insurance: Higher BMI often correlates with increased health risks (e.g., obesity-related conditions like diabetes or heart disease), leading to higher insurance charges.
# 4. Children
# Description: The number of children (dependents) covered under the individual’s insurance plan.
# Type: Numerical (integer).
# Example Values: 0, 1, 3, etc.
# Role in Insurance: More children can increase insurance costs slightly, as it may reflect additional healthcare needs, though the effect is often less pronounced than other factors like smoking or age.
# 5. Smoker
# Description: Indicates whether the individual smokes tobacco.
# Type: Categorical (text or binary).
# Example Values: "yes," "no" .
# Role in Insurance: Smoking is a major factor in insurance charges. Smokers typically have much higher medical costs due to risks like lung disease or cancer, so their charges are significantly elevated.
# 6. Region
# Description: The geographic region where the individual lives.
# Type: Categorical (text).
# Example Values: "northeast," "southeast," "southwest," "northwest" (common in U.S.-based datasets).
# Role in Insurance: Charges can vary by region due to differences in healthcare costs, lifestyle factors, or local insurance regulations.
# 7. Charges
# Description: The insurance charges (or premiums/costs) billed to the individual, typically in a currency like USD.
# Type: Numerical (float).
# Example Values: 1684.52, 11234.89, 32050.23, etc.
# Role in Insurance: This is usually the target variable (output) in predictive modeling. It represents the amount the insurance company charges, influenced by all the other columns (age, sex, BMI, etc.).

# %%
#1. Check if there is null value in dataset df (5 pt)
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#2. Assign charges to y  and others to X using df. y is output variable and X is input variables (5 pt)
y=df["charges"]
X=df.drop("charges",axis=1)

# %%
#3. Use  get_dummies() function from the pandas library to convert categorical variables in a DataFrame (X).
# Drop first drops the first category’s dummy variable to avoid multicollinearity (5 pt)
X=pd.get_dummies(X,drop_first=True)

# %%
#Use following methods for the evaluation on test and train data
def evalmetric(y,ypred):
 from scipy.stats import pearsonr
 import numpy as np
 e = y - ypred
 mse_f = np.mean(e**2)
 rmse_f = np.sqrt(mse_f)
 mae_f = np.mean(abs(e))
 mape_f = 100*np.mean(abs(e/y))
 crl, _ = pearsonr(y, ypred)
 r2_f = crl*crl
 print("MSE:", mse_f)
 print("RMSE:", rmse_f)
 print("MAE:",mae_f)
 print("MAPE:",mape_f)
 print("R-Squared:", round(r2_f, 4))

# %%
#4.Get the correlation between X variables and y variables.(5 pt)
X.corrwith(y)
# Out:
# age                 0.299008
# bmi                 0.198341
# children            0.067998
# sex_male            0.057292
# smoker_yes          0.787251
# region_northwest   -0.039905
# region_southeast    0.073982
# region_southwest   -0.043210
# dtype: float64

# %%
from sklearn.model_selection import train_test_split

#5.Split a dataset into 25%  of data as test data  and 75% of data as training data ( pt)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
#6. Using Decision Tree and Linear Regression methods, compare the performance results on both test and training data
#to determine which one is more likely to overfit and which is more likely to underfit.
# Do you think that Lasso and Ridge regularization are more likely to improve the results of Linear model test data,
# or would Random Forest or Boosting methods are more likely to improve the results of Decison tree test data?
#Explain your reasoning.(35 pt)
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression

dt = DecisionTreeRegressor()
lr = LinearRegression()
print("------Decision Tree-Train------")
evalmetric(y_train,dt.fit(X_train,y_train).predict(X_train))
print("------Decision Tree-Test------")
evalmetric(y_test,dt.fit(X_train,y_train).predict(X_test))
print("------Linear Regression-Train------")
evalmetric(y_train,lr.fit(X_train,y_train).predict(X_train))
print("------Linear Regression-Test------")
evalmetric(y_test,lr.fit(X_train,y_train).predict(X_test))
# Out:
# ------Decision Tree-Train------
# MSE: 260554.65921146877
# RMSE: 510.44554970287356
# MAE: 31.547947557328012
# MAPE: 0.9037448145117586
# R-Squared: 0.9982
# ------Decision Tree-Test------
# MSE: 39731949.93770418
# RMSE: 6303.328480866611
# MAE: 2941.02580758209
# MAPE: 38.37794533162609
# R-Squared: 0.7509
# ------Linear Regression-Train------
# MSE: 36649329.636657365
# RMSE: 6053.868980797104
# MAE: 4162.574149504561
# MAPE: 42.72773424919551
# R-Squared: 0.7456
# ------Linear Regression-Test------
# MSE: 36308308.86808894
# RMSE: 6025.637631660979
# MAE: 4096.247294855238
# MAPE: 37.86978964200055
# R-Squared: 0.7657

# %% [markdown]
# Question 6 continuance--> Linear Regression underfits and Decision Tree overfits. Linear regression performs bad in both test and train data. Decision tree performs good on train data, but bad on test data. Linear regression is too simple to catch the underlying patterns. Decision tree has too many variables so overfits.
# Lasso and Ridge will not help because they prevent overfitting; however, model underfits.
# Boosting and Random forest are more likely to help because they prevent overfitting which is the problem now.

# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

Ls=Lasso()
Rd=Ridge()
Rf=RandomForestRegressor()
Xgb=XGBRegressor()

print("------Lasso-Train------")
evalmetric(y_train,Ls.fit(X_train,y_train).predict(X_train))
print("------Lasso-Test------")
evalmetric(y_test,Ls.fit(X_train,y_train).predict(X_test))
print("------Ridge-Train------")
evalmetric(y_train,Rd.fit(X_train,y_train).predict(X_train))
print("------Ridge-Test------")
evalmetric(y_test,Rd.fit(X_train,y_train).predict(X_test))
print("------Random Forest-Train------")
evalmetric(y_train,Rf.fit(X_train,y_train).predict(X_train))
print("------Random Forest-Test------")
evalmetric(y_test,Rf.fit(X_train,y_train).predict(X_test))
print("------Boosting-Train------")
evalmetric(y_train,Xgb.fit(X_train,y_train).predict(X_train))
print("------Boosting-Test------")
evalmetric(y_test,Xgb.fit(X_train,y_train).predict(X_test))
# Out:
# ------Lasso-Train------
# MSE: 36649358.933184385
# RMSE: 6053.87140044983
# MAE: 4162.904486193335
# MAPE: 42.73818309189365
# R-Squared: 0.7456
# ------Lasso-Test------
# MSE: 36314895.47725804
# RMSE: 6026.184155604444
# MAE: 4096.998007620657
# MAPE: 37.88625262281414
# R-Squared: 0.7657
# ------Ridge-Train------
# MSE: 36652793.22538949
# RMSE: 6054.155038103128
# MAE: 4172.955480849132
# MAPE: 42.93360163394949
# R-Squared: 0.7456
# ------Ridge-Test------
# MSE: 36344224.53669136
# RMSE: 6028.617133032364
# MAE: 4108.8138156632
# MAPE: 38.05552417345894
# R-Squared: 0.7658
# ------Random Forest-Train------
# MSE: 3421157.7892209655
# RMSE: 1849.6372047569128
# MAE: 1002.2822797244789
# MAPE: 13.200247005159591
# R-Squared: 0.9772
# ------Random Forest-Test------
# MSE: 24446215.47566449
# RMSE: 4944.311425837221
# MAE: 2663.057063240538
# MAPE: 30.59344718995538
# R-Squared: 0.8412
# ------Boosting-Train------
# MSE: 739232.8214838944
# RMSE: 859.7864976166434
# MAE: 434.30258241102473
# MAPE: 6.751996652543464
# R-Squared: 0.995
# ------Boosting-Test------
# MSE: 27419844.50611423
# RMSE: 5236.396137241169
# MAE: 2961.0571549319616
# MAPE: 39.74092162580717
# R-Squared: 0.8235

# %%
#7. Explain performance of linear regressin on test data
# using  Root mean squared error, mean absolute error, mean absolute percentage error and R2 metric (10 pt)

# %%
# !pip install catboost

# %%
#8. Use Random Forest and Boosting methods (XGBoost, LightGBM, and CatBoost)
#to obtain the evaluation scores on  test data.
#Which Boosting technique yielded the best performance on the test data based on the R² metric?
#Did you achieve a better result compared to Random Forest on the test data based on the R² metric?
#If there is improvement on Random forest or boosting methods over decison tree, explain  (30 pt)

from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

xgb = XGBRegressor()
lgbm = LGBMRegressor(verbose=-1)
cat = CatBoostRegressor(verbose=False)

print("------XGBoost-Train------")
evalmetric(y_train,xgb.fit(X_train,y_train).predict(X_train))
print("------XGBoost-Test------")
evalmetric(y_test,xgb.fit(X_train,y_train).predict(X_test))
print("------LightGBM-Train------")
evalmetric(y_train,lgbm.fit(X_train,y_train).predict(X_train))
print("------LightGBM-Test------")
evalmetric(y_test,lgbm.fit(X_train,y_train).predict(X_test))
print("------CatBoost-Train------")
evalmetric(y_train,cat.fit(X_train,y_train).predict(X_train))
print("------CatBoost-Test------")
evalmetric(y_test,cat.fit(X_train,y_train).predict(X_test))
# Out:
# ------XGBoost-Train------
# MSE: 739232.8214838944
# RMSE: 859.7864976166434
# MAE: 434.30258241102473
# MAPE: 6.751996652543464
# R-Squared: 0.995
# ------XGBoost-Test------
# MSE: 27419844.50611423
# RMSE: 5236.396137241169
# MAE: 2961.0571549319616
# MAPE: 39.74092162580717
# R-Squared: 0.8235
# ------LightGBM-Train------
# MSE: 8059381.619650292
# RMSE: 2838.905003632614
# MAE: 1665.5821345236018
# MAPE: 22.061238363413008
# R-Squared: 0.9446
# ------LightGBM-Test------
# MSE: 24721409.82028859
# RMSE: 4972.062934063545
# MAE: 2875.4223535595297
# MAPE: 36.20198044907434
# R-Squared: 0.8394
# ------CatBoost-Train------
# MSE: 6392134.5535879675
# RMSE: 2528.267104874002
# MAE: 1386.2329026545474
# MAPE: 17.58800814568882
# R-Squared: 0.9563
# ------CatBoost-Test------
# MSE: 23279124.722483378
# RMSE: 4824.84452832248
# MAE: 2635.4342376141317
# MAPE: 31.03571246797772
# R-Squared: 0.8488
